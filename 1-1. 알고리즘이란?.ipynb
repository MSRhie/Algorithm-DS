# %% [markdown]
# * 깃허브와 연동하기 : https://velog.io/@shong676/Colab%EA%B3%BC-GitHub-%EC%97%B0%EB%8F%99%ED%95%98%EA%B8%B0

# %% [markdown]
# # 문제 : 입력받는 세 정수의 최댓값 구하기

# %%
# 1. 순서도 보고 문제 풀기 24.11.05

a = input()
b = input()
c = input()

maximum = a

if b > maximum :
  maximum = b
if c > maximum :
  maximum = c

print('최댓값 : ', maximum)
# Out:
# 1
# 2
# 3
# 최댓값 :  3

# %%
# 2. 함수 구현  24.11.05
def max3(a,b,c) :
  '''a,b,c의 최댓값을 구하여 반환'''
  maximum2 = a
  if b > maximum2 :
    maximum2 = b
  if c > maximum2 :
    maximum2 = c
  return maximum2

print(max3(4,5,6))
# Out:
# 6

# %% [markdown]
# # 문제 : 입력받는 세 정수의 대소 관계로 중앙값 구하기

# %%
# 1. 순서도 보고 코딩

def med(a,b,c) :
  if a >= b :
    if b >= c :
      return b
  if b >= c :
    if c >= a :
      return c
  if c >= a :
    if a >= b :
      return a
  else :
    return b

print(med(1,2,3))
# Out:
# None

# %% [markdown]
# # 깃 허브 업로드

# %%
cd /content/drive/MyDrive/7. Python/자료구조와 알고리즘/Algorithm-DS
# Out:
# /content/drive/MyDrive/7. Python/자료구조와 알고리즘/Algorithm-DS

# %%
# 3. 리펙토링 --

# %%
# !git add --all

# !git push
# Out:
# [main 6d1e0f7] 테스트
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  create mode 100644 "1-1. \341\204\213\341\205\241\341\206\257\341\204\200\341\205\251\341\204\205\341\205\265\341\204\214\341\205\263\341\206\267\341\204\213\341\205\265\341\204\205\341\205\241\341\206\253?.ipynb"
#  delete mode 100644 "\341\204\211\341\205\246 \341\204\214\341\205\245\341\206\274\341\204\211\341\205\256\341\204\213\341\205\264 \341\204\216\341\205\254\341\204\203\341\205\242\341\206\272\341\204\200\341\205\241\341\206\271 \341\204\200\341\205\256\341\204\222\341\205\241\341\204\200\341\205\265.ipynb"
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 2.10 KiB | 69.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/MSRhie/Algorithm-DS.git
#    e1941e4..6d1e0f7  main -> main

# %%
# !git commit -m '테스트'
